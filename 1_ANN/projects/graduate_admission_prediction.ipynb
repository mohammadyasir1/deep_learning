# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %% [markdown]
# # **Regression problem**

# %%
df = pd.read_csv('/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Serial No.'], inplace=True)

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 495              0.87
# 496              0.96
# 497              0.93
# 498              0.73
# 499              0.84
#
# [500 rows x 8 columns]

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
X_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 304        313          106                  2  2.5   2.0  8.43         0
# 340        312          107                  3  3.0   3.0  8.46         1
# 47         339          119                  5  4.5   4.0  9.70         0
# 67         316          107                  2  3.5   3.5  8.64         1
# 479        325          110                  4  4.5   4.0  8.96         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 11         327          111                  4  4.0   4.5  9.00         1
# 192        322          114                  5  4.5   4.0  8.94         1
# 92         298           98                  2  4.0   3.0  8.03         0
# 221        316          110                  3  3.5   4.0  8.56         0
# 110        305          108                  5  3.0   3.0  8.48         0
#
# [100 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7, activation='relu', input_dim=7))
model.add(Dense(7, activation='relu'))
# remember if you're working on regression problem then the activation of the output layer node is linear
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 7)                 56
#
#  dense_4 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 120 (480.00 Byte)
# Trainable params: 120 (480.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='Adam')

# %%
history = model.fit(X_train_scaled, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 21ms/step - loss: 1.1942 - val_loss: 1.2317
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0345 - val_loss: 1.0677
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8983 - val_loss: 0.9289
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7823 - val_loss: 0.8057
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6768 - val_loss: 0.6878
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5731 - val_loss: 0.5545
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4439 - val_loss: 0.3760
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2686 - val_loss: 0.1712
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1060 - val_loss: 0.0485
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0306 - val_loss: 0.0294
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0241 - val_loss: 0.0338
# Epoch 12/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0238 - val_loss: 0.0277
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0197 - val_loss: 0.0231
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0177 - val_loss: 0.0213
# Epoch 15/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0167 - val_loss: 0.0203
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0192
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0181
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0138 - val_loss: 0.0166
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0151
# Epoch 20/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0136
# Epoch 21/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0120
# Epoch 22/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0107
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0081 - val_loss: 0.0098
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0092
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 26/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 27/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0082
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0080
# Epoch 29/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 31/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0073
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 35/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0070
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 37/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 39/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0067
# Epoch 40/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0066
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0062
# Epoch 46/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0062
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0061
# Epoch 48/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0061
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 50/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 54/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 55/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 56/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0057
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 58/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 59/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 60/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 61/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 64/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 65/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 69/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 70/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 71/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 73/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 74/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 78/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 79/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 83/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 87/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 89/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 93/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 94/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 100/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0044

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.63316536],
#        [0.6889645 ],
#        [0.9279269 ],
#        [0.7252753 ],
#        [0.8368757 ],
#        [0.6522244 ],
#        [0.7616427 ],
#        [0.7150899 ],
#        [0.7856655 ],
#        [0.6071129 ],
#        [0.6685158 ],
#        [0.50486636],
#        [0.82144773],
#        [0.76983786],
#        [0.77863824],
#        [0.8721342 ],
#        [0.61492705],
#        [0.75921977],
#        [0.8866521 ],
#        [0.66882503],
#        [0.6248286 ],
#        [0.8035828 ],
#        [0.8705425 ],
#        [0.52825356],
#        [0.76766753],
#        [0.5658748 ],
#        [0.97321284],
#        [0.62764096],
#        [0.8759146 ],
#        [0.690348  ],
#        [0.61741626],
#        [0.83404493],
#        [0.61084986],
#        [0.9155165 ],
#        [0.5110533 ],
#        [0.82686317],
#        [0.68469703],
#        [0.6341553 ],
#        [0.6585281 ],
#        [0.901775  ],
#        [0.56605494],
#        [0.6372758 ],
#        [0.79232466],
#        [0.949229  ],
#        [0.77135444],
#        [0.55202746],
#        [0.68544316],
#        [0.64128375],
#        [0.652308  ],
#        [0.64996886],
#        [0.8555051 ],
#        [0.93013597],
#        [0.8544071 ],
#        [0.57891   ],
#        [0.767148  ],
#        [0.6096729 ],
#        [0.74517286],
#        [0.60865927],
#        [0.6373501 ],
#        [0.67593   ],
#        [0.41749242],
#        [0.69778824],
#        [0.767143  ],
#        [0.8375026 ],
#        [0.9761609 ],
#        [0.6019157 ],
#        [0.71578014],
#        [0.787063  ],
#        [0.9579935 ],
#        [0.695729  ],
#        [0.6026255 ],
#        [0.65868056],
#        [0.8300122 ],
#        [0.50953746],
#        [0.9412044 ],
#        [0.57788026],
#        [0.867066  ],
#        [0.95902085],
#        [0.7293389 ],
#        [0.76550734],
#        [0.8444201 ],
#        [0.48767623],
#        [0.8920145 ],
#        [0.8049331 ],
#        [0.75533235],
#        [0.6658988 ],
#        [0.89495885],
#        [0.88619876],
#        [0.5686306 ],
#        [0.6137059 ],
#        [0.6434411 ],
#        [0.8152101 ],
#        [0.5851015 ],
#        [0.67476225],
#        [0.7935296 ],
#        [0.8482356 ],
#        [0.83093333],
#        [0.5689559 ],
#        [0.69426537],
#        [0.64908934]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8154476661203854

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
