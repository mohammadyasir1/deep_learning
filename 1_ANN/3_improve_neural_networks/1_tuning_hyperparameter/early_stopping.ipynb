# %% [markdown]
# # Before Early stopping

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
# import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### Above you can see a overfitting on test dataset after 320 to 350 epochs

# %% [markdown]
# # After Applying Early stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 3s 213ms/step - loss: 0.6961 - accuracy: 0.4875 - val_loss: 0.6970 - val_accuracy: 0.5500
# Epoch 2/3500
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6937 - accuracy: 0.5250 - val_loss: 0.6997 - val_accuracy: 0.5500
# Epoch 3/3500
# 3/3 [==============================] - 0s 51ms/step - loss: 0.6915 - accuracy: 0.5125 - val_loss: 0.7011 - val_accuracy: 0.5500
# Epoch 4/3500
# 3/3 [==============================] - 0s 66ms/step - loss: 0.6904 - accuracy: 0.5000 - val_loss: 0.7033 - val_accuracy: 0.3500
# Epoch 5/3500
# 3/3 [==============================] - 0s 86ms/step - loss: 0.6890 - accuracy: 0.5125 - val_loss: 0.7054 - val_accuracy: 0.3000
# Epoch 6/3500
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6886 - accuracy: 0.5750 - val_loss: 0.7070 - val_accuracy: 0.3000
# Epoch 7/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6868 - accuracy: 0.5375 - val_loss: 0.7080 - val_accuracy: 0.3500
# Epoch 8/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6860 - accuracy: 0.5375 - val_loss: 0.7101 - val_accuracy: 0.4500
# Epoch 9/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6857 - accuracy: 0.5375 - val_loss: 0.7127 - val_accuracy: 0.4500
# Epoch 10/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6847 - accuracy: 0.5750 - val_loss: 0.7143 - val_accuracy: 0.4000
# Epoch 11/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6840 - accuracy: 0.5750 - val_loss: 0.7154 - val_accuracy: 0.4000
# Epoch 12/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6835 - accuracy: 0.5750 - val_loss: 0.7162 - val_accuracy: 0.4000
# Epoch 13/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6828 - accuracy: 0.5750 - val_loss: 0.7159 - val_accuracy: 0.4000
# Epoch 14/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6822 - accuracy: 0.5750 - val_loss: 0.7160 - val_accuracy: 0.4000
# Epoch 15/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6821 - accuracy: 0.5625 - val_loss: 0.7160 - val_accuracy: 0.4000
# Epoch 16/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6812 - accuracy: 0.5625 - val_loss: 0.7163 - val_accuracy: 0.4000
# Epoch 17/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6806 - accuracy: 0.5750 - val_loss: 0.7172 - val_accuracy: 0.4000
# Epoch 18/3500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6799 - accuracy: 0.5750 - val_loss: 0.7180 - val_accuracy: 0.4000
# Epoch 19/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6795 - accuracy: 0.5625 - val_loss: 0.7192 - val_accuracy: 0.4000
# Epoch 20/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6788 - accuracy: 0.5750 - val_loss: 0.7199 - val_accuracy: 0.4000
# Epoch 21/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6783 - accuracy: 0.5750 - val_loss: 0.7200 - val_accuracy: 0.4000
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 19s 2ms/step
